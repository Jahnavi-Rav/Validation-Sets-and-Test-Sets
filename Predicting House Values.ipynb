# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
train_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
scale_factor = 1000.0

# Scale the training set's label.
train_df["median_house_value"] /= scale_factor 

# Scale the test set's label
test_df["median_house_value"] /= scale_factor

# %%
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               


def train_model(model, df, feature, label, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
def plot_the_loss_curve(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 30
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split=0.2

# Identify the feature and the label.
my_feature="median_income"  # the median income on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions to build and train the model.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/30
# 13600/13600 [==============================] - 4s 273us/sample - loss: 38687.1737 - root_mean_squared_error: 196.6905 - val_loss: 46950.1193 - val_root_mean_squared_error: 216.6798
# Epoch 2/30
# 13600/13600 [==============================] - 0s 23us/sample - loss: 22220.1348 - root_mean_squared_error: 149.0642 - val_loss: 27340.6775 - val_root_mean_squared_error: 165.3502
# Epoch 3/30
# 13600/13600 [==============================] - 0s 23us/sample - loss: 11742.0044 - root_mean_squared_error: 108.3605 - val_loss: 14830.4222 - val_root_mean_squared_error: 121.7802
# Epoch 4/30
# 13600/13600 [==============================] - 0s 22us/sample - loss: 7109.8849 - root_mean_squared_error: 84.3201 - val_loss: 9459.9060 - val_root_mean_squared_error: 97.2621
# Epoch 5/30
# 13600/13600 [==============================] - 0s 26us/sample - loss: 6514.5744 - root_mean_squared_error: 80.7129 - val_loss: 9300.9265 - val_root_mean_squared_error: 96.4413
# Epoch 6/30
# 13600/13600 [==============================] - 0s 28us/sample - loss: 6513.9071 - root_mean_squared_error: 80.7088 - val_loss: 9323.3334 - val_root_mean_squared_error: 96.5574
# Epoch 7/30
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6514.1338 - root_mean_squared_error: 80.7102 - val_loss: 9285.2839 - val_root_mean_squared_error: 96.3602
# Epoch 8/30
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6512.6919 - root_mean_squared_error: 80.7012 - val_loss: 9332.2054 - val_root_mean_squared_error: 96.6033
# Epoch 9/30
# 13600/13600 [==============================] - 0s 22us/sample - loss: 6513.8111 - root_mean_squared_error: 80.7082 - val_loss: 9257.6924 - val_root_mean_squared_error: 96.2169
# Epoch 10/30
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6514.2415 - root_mean_squared_error: 80.7109 - val_loss: 9222.6144 - val_root_mean_squared_error: 96.0344
# Epoch 11/30
# 13600/13600 [==============================] - 0s 19us/sample - loss: 6510.7853 - root_mean_squared_error: 80.6894 - val_loss: 9285.8946 - val_root_mean_squared_error: 96.3633
# Epoch 12/30
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6514.5862 - root_mean_squared_error: 80.7130 - val_loss: 9258.8220 - val_root_mean_squared_error: 96.2228
# Epoch 13/30
# 13600/13600 [==============================] - ETA: 0s - loss: 6540.7611 - root_mean_squared_error: 80.875 - 0s 21us/sample - loss: 6513.8215 - root_mean_squared_error: 80.7083 - val_loss: 9232.6696 - val_root_mean_squared_error: 96.0868
# Epoch 14/30
# 13600/13600 [==============================] - 0s 19us/sample - loss: 6512.6132 - root_mean_squared_error: 80.7008 - val_loss: 9358.5457 - val_root_mean_squared_error: 96.7396
# Epoch 15/30
# 13600/13600 [==============================] - 0s 24us/sample - loss: 6513.3969 - root_mean_squared_error: 80.7056 - val_loss: 9204.1475 - val_root_mean_squared_error: 95.9382
# Epoch 16/30
# 13600/13600 [==============================] - 0s 36us/sample - loss: 6513.7246 - root_mean_squared_error: 80.7076 - val_loss: 9275.2335 - val_root_mean_squared_error: 96.3080
# Epoch 17/30
# 13600/13600 [==============================] - 1s 41us/sample - loss: 6513.9048 - root_mean_squared_error: 80.7088 - val_loss: 9214.6033 - val_root_mean_squared_error: 95.9927
# Epoch 18/30
# 13600/13600 [==============================] - 0s 36us/sample - loss: 6514.2674 - root_mean_squared_error: 80.7110 - val_loss: 9258.4748 - val_root_mean_squared_error: 96.2210
# Epoch 19/30
# 13600/13600 [==============================] - 1s 63us/sample - loss: 6513.3856 - root_mean_squared_error: 80.7055 - val_loss: 9253.1732 - val_root_mean_squared_error: 96.1934
# Epoch 20/30
# 13600/13600 [==============================] - 1s 45us/sample - loss: 6513.6968 - root_mean_squared_error: 80.7075 - val_loss: 9401.4261 - val_root_mean_squared_error: 96.9610
# Epoch 21/30
# 13600/13600 [==============================] - 0s 17us/sample - loss: 6513.6505 - root_mean_squared_error: 80.7072 - val_loss: 9207.3727 - val_root_mean_squared_error: 95.9551
# Epoch 22/30
# 13600/13600 [==============================] - 0s 29us/sample - loss: 6514.5313 - root_mean_squared_error: 80.7126 - val_loss: 9296.4127 - val_root_mean_squared_error: 96.4179
# Epoch 23/30
# 13600/13600 [==============================] - 0s 28us/sample - loss: 6513.1095 - root_mean_squared_error: 80.7038 - val_loss: 9390.0905 - val_root_mean_squared_error: 96.9025
# Epoch 24/30
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6514.4822 - root_mean_squared_error: 80.7123 - val_loss: 9302.1697 - val_root_mean_squared_error: 96.4478
# Epoch 25/30
# 13600/13600 [==============================] - 0s 18us/sample - loss: 6513.5286 - root_mean_squared_error: 80.7064 - val_loss: 9382.2096 - val_root_mean_squared_error: 96.8618
# Epoch 26/30
# 13600/13600 [==============================] - 0s 19us/sample - loss: 6514.0081 - root_mean_squared_error: 80.7094 - val_loss: 9397.9775 - val_root_mean_squared_error: 96.9432
# Epoch 27/30
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6513.1664 - root_mean_squared_error: 80.7042 - val_loss: 9232.2223 - val_root_mean_squared_error: 96.0844
# Epoch 28/30
# 13600/13600 [==============================] - 0s 36us/sample - loss: 6513.8754 - root_mean_squared_error: 80.7086 - val_loss: 9356.3142 - val_root_mean_squared_error: 96.7280
# Epoch 29/30
# 13600/13600 [==============================] - 0s 16us/sample - loss: 6512.5386 - root_mean_squared_error: 80.7003 - val_loss: 9397.7908 - val_root_mean_squared_error: 96.9422
# Epoch 30/30
# 13600/13600 [==============================] - 0s 18us/sample - loss: 6513.2438 - root_mean_squared_error: 80.7047 - val_loss: 9291.3852 - val_root_mean_squared_error: 96.3918
# 84.66071

# %%
# Examine examples 0 through 4 and examples 25 through 29
# of the training set
train_df.head(n=1000)

# The original training set is sorted by longitude. 
# Apparently, longitude influences the relationship of
# total_rooms to median_house_value.
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -114.3      34.2                15.0       5612.0          1283.0
# 1       -114.5      34.4                19.0       7650.0          1901.0
# 2       -114.6      33.7                17.0        720.0           174.0
# 3       -114.6      33.6                14.0       1501.0           337.0
# 4       -114.6      33.6                20.0       1454.0           326.0
# ..         ...       ...                 ...          ...             ...
# 995     -117.1      32.5                 8.0       6533.0          1217.0
# 996     -117.1      34.6                 6.0       5110.0          1044.0
# 997     -117.1      34.2                22.0       4397.0           931.0
# 998     -117.1      34.0                24.0       4144.0           826.0
# 999     -117.1      33.6                 6.0       1868.0           289.0
#
#      population  households  median_income  median_house_value
# 0        1015.0       472.0            1.5                66.9
# 1        1129.0       463.0            1.8                80.1
# 2         333.0       117.0            1.7                85.7
# 3         515.0       226.0            3.2                73.4
# 4         624.0       262.0            1.9                65.5
# ..          ...         ...            ...                 ...
# 995      4797.0      1177.0            4.0               144.4
# 996      1938.0       724.0            3.2               112.8
# 997      1145.0       445.0            4.5               108.4
# 998      2127.0       772.0            2.5                96.0
# 999       750.0       247.0            4.4               307.6
#
# [1000 rows x 9 columns]

# %%
# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 70
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split=0.2

# Identify the feature and the label.
my_feature="median_income"  # the median income on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Shuffle the examples.
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index)) 

# Invoke the functions to build and train the model. Train on the shuffled
# training set.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, shuffled_train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/70
# 13600/13600 [==============================] - 1s 63us/sample - loss: 44525.8620 - root_mean_squared_error: 211.0115 - val_loss: 34961.5007 - val_root_mean_squared_error: 186.9800
# Epoch 2/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 26019.1565 - root_mean_squared_error: 161.3046 - val_loss: 19659.7381 - val_root_mean_squared_error: 140.2132
# Epoch 3/70
# 13600/13600 [==============================] - 0s 20us/sample - loss: 13992.8509 - root_mean_squared_error: 118.2914 - val_loss: 10554.3533 - val_root_mean_squared_error: 102.7344
# Epoch 4/70
# 13600/13600 [==============================] - 0s 22us/sample - loss: 8038.2550 - root_mean_squared_error: 89.6563 - val_loss: 7379.3489 - val_root_mean_squared_error: 85.9031
# Epoch 5/70
# 13600/13600 [==============================] - 0s 22us/sample - loss: 6954.2038 - root_mean_squared_error: 83.3919 - val_loss: 7301.8940 - val_root_mean_squared_error: 85.4511
# Epoch 6/70
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6943.7064 - root_mean_squared_error: 83.3289 - val_loss: 7301.8659 - val_root_mean_squared_error: 85.4510
# Epoch 7/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6940.0962 - root_mean_squared_error: 83.3072 - val_loss: 7328.7219 - val_root_mean_squared_error: 85.6080
# Epoch 8/70
# 13600/13600 [==============================] - 0s 23us/sample - loss: 6945.8258 - root_mean_squared_error: 83.3416 - val_loss: 7306.7681 - val_root_mean_squared_error: 85.4796
# Epoch 9/70
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6944.2303 - root_mean_squared_error: 83.3320 - val_loss: 7299.3998 - val_root_mean_squared_error: 85.4365
# Epoch 10/70
# 13600/13600 [==============================] - 0s 32us/sample - loss: 6943.8580 - root_mean_squared_error: 83.3298 - val_loss: 7302.3327 - val_root_mean_squared_error: 85.4537
# Epoch 11/70
# 13600/13600 [==============================] - 1s 37us/sample - loss: 6943.3785 - root_mean_squared_error: 83.3269 - val_loss: 7297.3693 - val_root_mean_squared_error: 85.4246
# Epoch 12/70
# 13600/13600 [==============================] - 0s 27us/sample - loss: 6942.5976 - root_mean_squared_error: 83.3222 - val_loss: 7307.0496 - val_root_mean_squared_error: 85.4813
# Epoch 13/70
# 13600/13600 [==============================] - 0s 22us/sample - loss: 6943.7430 - root_mean_squared_error: 83.3291 - val_loss: 7297.7652 - val_root_mean_squared_error: 85.4270
# Epoch 14/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 
70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6942.9993 - root_mean_squared_error: 83.3247 - val_loss: 7297.3930 - val_root_mean_squared_error: 85.4248
# Epoch 54/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6943.2726 - root_mean_squared_error: 83.3263 - val_loss: 7298.8083 - val_root_mean_squared_error: 85.4331
# Epoch 55/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6943.7415 - root_mean_squared_error: 83.3291 - val_loss: 7300.6208 - val_root_mean_squared_error: 85.4437
# Epoch 56/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6943.1950 - root_mean_squared_error: 83.3259 - val_loss: 7298.3629 - val_root_mean_squared_error: 85.4305
# Epoch 57/70
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6943.8250 - root_mean_squared_error: 83.3296 - val_loss: 7299.8623 - val_root_mean_squared_error: 85.4392
# Epoch 58/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6943.2406 - root_mean_squared_error: 83.3261 - val_loss: 7305.6849 - val_root_mean_squared_error: 85.4733
# Epoch 59/70
# 13600/13600 [==============================] - 0s 22us/sample - loss: 6944.0943 - root_mean_squared_error: 83.3312 - val_loss: 7300.1552 - val_root_mean_squared_error: 85.4409
# Epoch 60/70
# 13600/13600 [==============================] - 0s 29us/sample - loss: 6943.5494 - root_mean_squared_error: 83.3280 - val_loss: 7305.5151 - val_root_mean_squared_error: 85.4723
# Epoch 61/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6940.6191 - root_mean_squared_error: 83.3104 - val_loss: 7305.8806 - val_root_mean_squared_error: 85.4744
# Epoch 62/70
# 13600/13600 [==============================] - 0s 22us/sample - loss: 6943.0396 - root_mean_squared_error: 83.3249 - val_loss: 7299.4521 - val_root_mean_squared_error: 85.4368
# Epoch 63/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6943.8736 - root_mean_squared_error: 83.3299 - val_loss: 7298.6157 - val_root_mean_squared_error: 85.4319
# Epoch 64/70
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6943.1716 - root_mean_squared_error: 83.3257 - val_loss: 7307.8999 - val_root_mean_squared_error: 85.4863
# Epoch 65/70
# 13600/13600 [==============================] - 0s 24us/sample - loss: 6943.5644 - root_mean_squared_error: 83.3280 - val_loss: 7298.6648 - val_root_mean_squared_error: 85.4322
# Epoch 66/70
# 13600/13600 [==============================] - 0s 27us/sample - loss: 6943.6988 - root_mean_squared_error: 83.3289 - val_loss: 7298.2277 - val_root_mean_squared_error: 85.4297
# Epoch 67/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6944.3147 - root_mean_squared_error: 83.3326 - val_loss: 7297.7811 - val_root_mean_squared_error: 85.4270
# Epoch 68/70
# 13600/13600 [==============================] - 0s 21us/sample - loss: 6942.8643 - root_mean_squared_error: 83.3239 - val_loss: 7300.6172 - val_root_mean_squared_error: 85.4436
# Epoch 69/70
# 13600/13600 [==============================] - 0s 24us/sample - loss: 6942.8860 - root_mean_squared_error: 83.3240 - val_loss: 7298.9131 - val_root_mean_squared_error: 85.4337
# Epoch 70/70
# 13600/13600 [==============================] - 0s 20us/sample - loss: 6943.6203 - root_mean_squared_error: 83.3284 - val_loss: 7303.8936 - val_root_mean_squared_error: 85.4628
# 77.997856

# %%
x_test = test_df[my_feature]
y_test = test_df[my_label]

results = my_model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 3000/3000 [==============================] - 0s 17us/sample - loss: 7015.7951 - root_mean_squared_error: 83.7603
